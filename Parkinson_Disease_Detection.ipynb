# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
parkinson_data = pd.read_excel('/content/parkinsons.xlsx')

# %%
parkinson_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
parkinson_data.shape
# Out:
# (195, 24)

# %%
parkinson_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
parkinson_data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
parkinson_data['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %%
X = parkinson_data.drop(columns=['name', 'status'], axis = 1)
Y = parkinson_data['status']

# %%
print(X)
print(Y)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,stratify = Y random_state=2)
# Out:
#   File "<ipython-input-70-1b111ca97484>", line 1
#     X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,stratify = Y random_state=2)
#                                                                                                     ^
# SyntaxError: invalid syntax

# %%
print(X.shape, X_train.shape, X_test.shape)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"

# %%
print(X_train, X_test)
# Out:
# [[ -3.88357402  -2.21136142  -2.67820406 ... -14.13619174  -7.43398589
#    -1.40095732]
#  [ -3.92558841  -2.22028877  -2.67929626 ...   2.03334088  -7.58178165
#     1.97997024]
#  [ -3.89857287  -2.2143296   -2.68364539 ...  -7.82281343  -7.6281252
#    -7.69875455]
#  ...
#  [ -3.92196717  -2.21840995  -2.66205008 ...  11.7044837   -7.23817005
#    -4.55043112]
#  [ -3.90827623  -2.20887359  -2.67620026 ...  -4.75835305  -7.2348425
#     0.78830544]
#  [ -3.87393451  -2.20885249  -2.67234855 ... -11.08087115  -2.91983105
#    -2.85950719]] [[-3.94164600e+00 -2.22177948e+00 -2.67573967e+00 -5.37142148e+01
#    1.13219504e+04 -9.22851596e+01 -3.39971509e+01 -3.13805667e+01
#   -2.64377653e+01 -3.80686837e+00 -5.13375442e+01 -3.53777404e+01
#   -2.12813048e+01 -1.81401676e+01 -8.67012225e+00 -4.69010264e+00
#    5.36686266e+00  6.29197411e+00  5.35898300e+00  2.02814830e+01
#   -5.94865285e+00  2.53122594e+00]
#  [-3.93393674e+00 -2.22135544e+00 -2.67499657e+00  1.40362782e+02
# ...

# %%
model = svm.SVC(kernel='linear')

# %%
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
training_data_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(training_data_prediction, Y_train)
print('accuracy of training data: ', training_data_accuracy)
# Out:
# accuracy of training data:  0.9038461538461539

# %%
testing_data_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(testing_data_prediction, Y_test)
print('accuracy of testing data', testing_data_accuracy)
# Out:
# accuracy of testing data 0.717948717948718

# %%
input_data = (122.40000,148.65000,113.81900,0.00968,0.00008,0.00465,0.00696,0.01394,0.06134,0.62600,0.03134,0.04518,0.04368,0.09403,0.01929,19.08500,0.458359,0.819521,-4.075192,0.335590,2.486855,0.368674)

input_data_as_array = np.asarray(input_data)

reshaped_input_data = input_data_as_array.reshape(1, -1)

standerdize_data = scaler.transform(reshaped_input_data)

prediction = model.predict(standerdize_data)

if(prediction == 1):
  print('patient have parkinson disease')
else:
  print('patient doesnot have parkinson disease')
# Out:
# patient have parkinson disease
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
